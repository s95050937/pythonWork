# %%
import requests
from pyquery import PyQuery as pq

# %%
HomeRes = requests.get("https://www.rt-mart.com.tw/direct/")
# HomeRes.text
HomeDoc = pq(HomeRes.text)
print(HomeDoc)
# Out:
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns="http://www.w3.org/1999/xhtml" lang="zh-tw" xml:lang="zh-tw">&#13;
# <!---->&#13;
# <head id="page_head">
# <title>大潤發網路購物中心 - 網路購物天天低價</title>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="edge" />
# <meta name="keywords" content=" 大潤發,大潤發網購,大潤發網路購物,購物網,網路購物,線上購物,rtmart" />
# <meta name="description" content=" 大潤發網路購物提供進口食品、沖泡飲料、3C家電、零食點心、居家生活等線上購物商品優惠，大潤發網路首購會員、限時特賣眾多優惠量販價網路直購送到家，大潤發網路購物天天低價！" />
# <meta name="google-site-verification" content="EggAN2jnInsHbl8CObBTy1v-Oafp592TCgcV9Nv-9fw" />
# <link href="https://www.rt-mart.com.tw/direct/css/fck_editorarea.css" rel="stylesheet" type="text/css" />
# <link href="https://www.rt-mart.com.tw/direct/css/df_style.css" rel="stylesheet" type="text/css" />
# <link href="https://www.rt-mart.com.tw/direct/templates/web_style/rtmart/color_1/zh-tw/style.css" rel="stylesheet" type="text/css" />
# <link rel="stylesheet" type="text/css" href="https://www.rt-mart.com.tw/direct/templates/web_style/rtmart/color_1/zh-tw/css/style.css" />
# <link rel="stylesheet" type="text/css" href="https://www.rt-mart.com.tw/direct/templates/web_style/rtmart/color_1/zh-tw/css/jquery.jscrollpane.css" />
# <script type="text/javascript" src="https://www.rt-mart.com.tw/direct/templates/web_style/rtmart/color_1/zh-tw/js/jquery-1.9.1.min.js"></script>
# <script type="text/javascript" src="https://www.rt-mart.com.tw/direct/templates/web_style/rtmart/color_1/zh-tw/js/jquery.masonry.min.js"></script>
# <script type="text/javascript" src="https://www.rt-mart.com.tw/direct/templates/web_style/rtmart/color_1/zh-tw/js/jquery.slides.js"></script>
# <link rel="stylesheet" type="text/css" media="screen" href="https://www.rt-mart.com.tw/direct/templates/web_style/rtmart/color_1/zh-tw/js/fancybox/jquery.fancybox.css" />
# <script type="text/javascript" src="https://www.rt-mart.com.tw/direct/templates/web_style/rtmart/color_1/zh-tw/js/fancybox/jquery.fancybox.pack.js"></script>
# <link rel="stylesheet" type="text/css" media="screen" href="https://www.rt-mart.com.tw/direct/templates/web_style/rtmart/color_1/zh-tw/js/jqtransform/jqtransform.css" />
# <script type="text/javascript" src="https://www.rt-mart.com.tw/direct/templates/web_style/rtmart/color_1/zh-tw/js/jqtransform/jquery.jqtransform.js"></script>
# <script type="text/javascript" src="https://www.rt-mart.com.tw/direct/templates/web_style/rtmart/color_1/zh-tw/js/jquery.loupe.min.js"></script>
# <script type="text/javascript" src="https://www.rt-mart.com.tw/direct/templates/web_style/rtmart/color_1/zh-tw/js/jquery.jscrollpane.min.js"></script>
# <script type="text/javascript" src="https://www.rt-mart.com.tw/direct/templates/web_style/rtmart/color_1/zh-tw/js/jquery.mousewheel.js"></script>
# <script type="text/javascript" src="https://www.rt-mart.com.tw/direct/templates/web_style/rtmart/color_1/zh-tw/js/function.js"></script>
# <script language="javascript" type="text/javascript" src="https://www.rt-mart.com.tw/direct/javascripts/ij-ajax/ij-ajax.js"></script>
# <script language="javascript">
# var IJ = new IJ("https://www.rt-mart.com.tw/direct/javascripts/ij-ajax/");
# //IJ.loadJs();
# var menu_move_x = 0; /**/
# var menu_move_y = 0; /**/
# </script>
# <link rel="icon" href="https://www.rt-mart.com.tw/website/uploads/website_2/zh-tw/favicon_2.ico" type="image/x-icon" />
# <link rel="shortcut icon" href="https://www.rt-mart.com.tw/website/uploads/website_2/zh-tw/favicon_2.ico" type="image/x-icon" />
# <link rel="bookmark" href="https://www.rt-mart.com.tw/website/uploads/website_2/zh-tw/favicon_2.ico" type="image/x-icon" />
#
# <!--Google Analytics USERID-->
# <!--20170309-->
# <script type="text/javascript">
#         //取得mem_uid的cookie
#         function getCookie(){
#         cookieArray = document.cookie.split(";")
#         for(var i = 0;i &lt; cookieArray.length;i++){
#         	var temp = cookieArray[i].split("=");
#         	if(temp[0].match('mem_uid'))
#         		return unescape(temp[1]);
#         }
#     }
#
#
# rtuserid = getCookie();//uesrID
# </script>
#
#
# <script>
# dataLayer = [{
#
# 'userID': rtuserid
#
# }];
# </script>
#
# <!-- Google Tag Manager -->
# <!--	20170105	-->
# <!---->
#
# <!---->
#
# <!---->
#
# <!---->
#
# <!---->
#
# <!---->
#
# <!---->
#
# <!---->
#
#
#
#
# <script>
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&amp;l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-K6W8RTB');
# </script>
# <!-- End Google Tag Manager -->
# <!--End Google Analytics USERID-->
#
# <script type="text/javascript">
# 	function checkPasswd(passwd)
# 	{
# 		if( passwd.length &lt; 6 || passwd.length &gt; 12 ) {
# 			alert("密碼需 8 ~ 12 碼，建議使用英數混和，請勿使用!、~等特殊字元");
# 			return false;
# 		}
#
# 		var aa=0; // 小寫英文字
# 		var bb=0; // 大寫英文字
# 		var cc=0; // 數字
# 		var dd=0; // 其他符號
# 		for (var i = 0 ; i &lt; passwd.length ; i++ ) {
# 			if(( passwd.charAt(i)&gt;= 'a' &amp;&amp; passwd.charAt(i) &lt;= 'z' )) {
# 				aa++;
# 			} else if (( passwd.charAt(i)&gt;= '0' &amp;&amp; passwd.charAt(i) &lt;= '9' )){
# 				bb++;
# 			} else if (passwd.charAt(i)&gt;= 'A' &amp;&amp; passwd.charAt(i) &lt;= 'Z') {
# 				cc++;
# 			} else {
# 				dd++;
# 			}
# 		}
# 		// var mem_account = '';
# 		//if (passwd.substring(0, mem_account.length) == mem_account) {
# 		//	alert('您的密碼內包括帳號訊息!');
# 		//	return false;
# 		//}
# 		//else if (passwd.length &gt; mem_account.length &amp;&amp; passwd.substring(passwd.length-mem_account.length) == mem_account) {
# 		//	alert('您的密碼內包括帳號訊息!');
# 		//	return false;
# 		//}
#
# 		// if(parseInt(aa)+parseInt(bb)&gt;=7 &amp;&amp; aa!=0 &amp;&amp; bb!=0 || parseInt(bb)+parseInt(cc)&gt;=7 &amp;&amp; bb!=0 &amp;&amp; cc!=0 || parseInt(aa)+parseInt(bb)+parseInt(cc)&gt;=7 &amp;&amp; aa!=0 &amp;&amp; bb!=0 &amp;&amp; cc!=0){
# 		if (aa + cc &gt;= 1 &amp;&amp; bb &gt;= 1) {
# 			/*	var dictionaryArray = dictionaryString.split('|');
#
# 			if (bb &lt; 6) {
# 				for (i = 0; i &lt; dictionaryArray.length; i ++) {
# 					if (passwd.substring(0, dictionaryArray[i].length) == dictionaryArray[i]) {
# 						alert('您的密碼內包括字典常用字!');
# 						return false;
# 					}
# 					else if (passwd.length &gt; dictionaryArray[i].length &amp;&amp; passwd.substring(passwd.length-dictionaryArray[i].length) == dictionaryArray[i]) {
# 						alert('您的密碼內包括字典常用字!');
# 						return false;
# 					}
# 				}
# 			}
# 			*/
# 			// alert("OK");
# 			return true;
# 		} else {
# 			alert("您的密碼只能是英文字母加數字組合，不能含空白鍵、*、@、#、%或其他符號 !");
# 			return false;
# 		}
# 	}
# </script>
#
# <script>var section = 1;</script>
# <!--[if IE]>
# <style type="text/css">
# .ie-hack {behavior:url(https://www.rt-mart.com.tw/direct/templates/web_style/rtmart/color_1/zh-tw/js/ie-css3.htc);}
# </style>
# <![endif]-->
# <script>
# $(function() {
# 			var $container = $('.masonryContainer');
# 	$container.imagesLoaded( function(){
# 	$container.masonry({
# 			itemSelector : '.masonryBox',
# 			columnWidth: 282,
#             isAnimated: true
# 		});
# 	});
# 		$('#slides, #slides2, #slides3, #slides4').slidesjs({
# 		width: 335,
# 		height: 535,
# 		play: 5000,
# 		navigation: false,
# 		play: {
#           auto: true,
# 		  pauseOnHover: true
#         }
# 	});
#
# 	if ($(document).width()&lt;1030){
# 		$('.maContainer').css({'width':846});
# 	} else {
# 		$('.maContainer').css({'width':'100%'});
# 	}
# 	$('.overlayer').css({'visibility':'hidden', 'display':'block'});
# 	$('.txt').css({'top':($('.slides_container').height()-$('.txt').height())/2});
# 	$('.slidesjs-pagination').css({'top':($('.slides_container').height()+20)/2});
# 	$('.overlayer').css({'visibility':'visible', 'display':'none'});
#
# 	$(window).resize(function() {
# 		$('.overlayer').css({'visibility':'hidden', 'display':'block'});
# 		//$('.txt').css({'top':($('.slides_container').height()-$('.txt').height())/2});
# 		$('.slidesjs-pagination').css({'top':($('.slides_container').height()+20)/2});
# 		$('.overlayer').css({'visibility':'visible', 'display':'none'});
# 		if ($(document).width()&lt;1030){
# 			$('.maContainer').css({'width':846});
# 		} else {
# 			$('.maContainer').css({'width':'100%'});
# 		}
# 	})
# });
# </script>
# <script>
# $(document).ready(function() {
# 	$('.scroll-pane').jScrollPane();
# })
# </script>
# <!-- Global site tag (gtag.js) - Google Ads: 771948069 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-771948069"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'AW-771948069');
# </script>
# </head>
#
# <body>
#
# <!-- Google Tag Manager (noscript) -->
# <!--	20170105	-->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-K6W8RTB" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
# <!--Google Matching tag (PIXEL)-->
# <!--img src =“http://cm.g.doubleclick.net/pixel?google_nid=rtmart_dmp&google_cm”/-->
#
#
#
#
# <noscript>
# <!--	20170105
# <div style="display:inline;">
# <img height="1" width="1" style="border-style:none;" alt="" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/924675721/?value=0&amp;guid=ON&amp;script=0"/>
# </div>
# -->
# </noscript>
# </body>&#13;
# <style>&#13;
# /*&#13;
# jin2017/01/25&#13;
# 僅供首頁使用&#13;
# */&#13;
# &#13;
# /* Modal Content (image) */&#13;
# .modal-content {&#13;
#     margin: auto;&#13;
#     display: block;&#13;
#     width: 1000px;&#13;
#     /* margin-left: -0px; */&#13;
#     max-width: 1000px;&#13;
# }&#13;
# &#13;
# /* Add Animation */&#13;
# .modal-content {    &#13;
#     -webkit-animation-name: zoom;&#13;
#     -webkit-animation-duration: 0.3s;&#13;
#     animation-name: zoom;&#13;
#     animation-duration: 0.3s;&#13;
# }&#13;
# &#13;
# @-webkit-keyframes zoom {&#13;
#     from {-webkit-transform:scale(0)} &#13;
#     to {-webkit-transform:scale(1)}&#13;
# }&#13;
# &#13;
# @keyframes zoom {&#13;
#     from {transform:scale(0)} &#13;
#     to {transform:scale(1)}&#13;
# }&#13;
# &#13;
# /* The Close Button */&#13;
# &#13;
# &#13;
# .close:hover,&#13;
# .close:focus {&#13;
#     color: #bbb;&#13;
#     text-decoration: none;&#13;
#     cursor: pointer;&#13;
# }&#13;
# &#13;
# /* 100% Image Width on Smaller Screens */&#13;
# @media only screen and (max-width: 700px){&#13;
#     .modal-content {&#13;
#         width: 100%;&#13;
#     }&#13;
# }&#13;
# &#13;
# &#13;
# &#13;
# #idleAd {&#13;
# &#13;
#     position: fixed;&#13;
#     width: 100%;&#13;
#     height: 1500px;&#13;
#     left: 0px;&#13;
#     top: 0px;&#13;
#     z-index: 51;&#13;
# }&#13;
# &#13;
# #idleAd .inner {&#13;
#     width: 700px;&#13;
#     height: 355px;&#13;
#     margin: 117px auto 0 auto;&#13;
#     border-radius: 10px;&#13;
#     position: relative;&#13;
#     z-index: 2;&#13;
# }&#13;
# #idleAd .inner .box_0 {&#13;
#     position: relative;&#13;
#     top: 3px;&#13;
#     left: -150px;&#13;
#     margin-bottom: 10px;&#13;
# }&#13;
# &#13;
# #idleAd .close {&#13;
#     display: block;&#13;
#     width: 70px;&#13;
#     height: 25px;&#13;
#     position: absolute;&#13;
#     top: -30px;&#13;
#     right: -150px;&#13;
#     cursor: pointer;&#13;
#     padding-top: 5px;&#13;
#     border-radius: 5px;&#13;
#     background-color: black;&#13;
#     color: white;&#13;
# }&#13;
# &#13;
# #idleAd .overlap {&#13;
#     width: 100%;&#13;
#     height: 1500px;&#13;
#     background-color: rgba(255, 255, 255, 0.61);&#13;
#     z-index: 1;&#13;
#     filter: alpha(opacity=60);&#13;
#     opacity: 0.6;&#13;
#     position: absolute;&#13;
#     left: 0px;&#13;
#     top: 0px;&#13;
# }&#13;
# &#13;
# /*#idleAd a{&#13;
#     color: rgba(47, 79, 79, 0);&#13;
#     font-size: 50px;&#13;
#     font-weight: bolder;&#13;
#     width: 740px;&#13;
#     height: 150px;&#13;
#     text-align: center;&#13;
#     padding-top: 80px;&#13;
#     top: 80px;&#13;
#     opacity: 0.9;&#13;
#     text-decoration: none;&#13;
#     position: absolute;&#13;
#     background-color: rgba(47, 79, 79, 0);&#13;
# &#13;
# }*/&#13;
# 	body{margin:0;padding:0;}&#13;
# 	canvas{position:absolute;top:0;left:0;}&#13;
# &#13;
# 	&#13;
# /*&#13;
# jin2017/01/25&#13;
# 僅供首頁結束&#13;
# */&#13;
# &#13;
# &#13;
# &#13;
# .warning {&#13;
# 	background: #000;&#13;
#     text-align: center;&#13;
#     position: fixed;&#13;
#     bottom: 0;&#13;
#     width: 100%;&#13;
#     z-index: 1000;}&#13;
# 	&#13;
# .warning2 {&#13;
# 	background: #000;&#13;
#     text-align: center;&#13;
#     position: fixed;&#13;
# 	left:0;&#13;
#     bottom: 0;&#13;
#     width: 100%;&#13;
#     z-index: 1000;}&#13;
# &#13;
# .FOR_FOOTER{&#13;
# 	margin-bottom: 0 !important;&#13;
# }&#13;
# #footernav{&#13;
# 	margin-top:50px;&#13;
# 	margin-bottom: -15px;&#13;
# }&#13;
# #footertop{&#13;
#     margin: 0 auto;&#13;
# 	background-color: #fdfdfd;&#13;
# }&#13;
# #footersocial{&#13;
#     margin: 0 auto;&#13;
# 	background-color: #ffffff;&#13;
# }&#13;
# #footerbottom{&#13;
# 	padding:1px;&#13;
#     margin: 0 auto;&#13;
#     background-color: #fdfdfd;&#13;
# }&#13;
# #footersocial ul,#footertop ul {&#13;
# 	list-style: none ;&#13;
# }&#13;
# #footer a{&#13;
# 	text-decoration: none;&#13;
# }&#13;
# #footerbottom p{&#13;
# 	 text-align:center;&#13;
# 	 font-size:10px;&#13;
# 	 color:#444444;&#13;
# }&#13;
# .footerwidth{&#13;
#     min-width: 900px;&#13;
#     width: 990px;&#13;
# 	font: 10px Helvetica;&#13;
# 	color: #FFFFFF;&#13;
# 	margin: 0px auto;&#13;
#     position: relative;&#13;
# }&#13;
# .footer1,.footer2{&#13;
#     text-align: center;&#13;
# }&#13;
# .footer3{&#13;
# 	height:120px;&#13;
# }&#13;
# &#13;
# .footer1{&#13;
#     padding: 10px 0px;&#13;
#     height: 130px;&#13;
# 	padding-bottom: 15px;&#13;
# 	border-bottom: 1px dotted #c9c9c9;&#13;
# }&#13;
# .footer2{&#13;
#     height: 230px;&#13;
# 	padding-bottom: 15px;&#13;
# }&#13;
# .footersocialcontent ul {&#13;
# 	float:left;&#13;
# }&#13;
# &#13;
# .footerNavCategory h2{&#13;
# 	font-weight: 700;&#13;
#     margin-left: 15px;&#13;
#     font-size: 13px;&#13;
#     padding-left: 8px;&#13;
#     color: #222;&#13;
#     background-repeat: no-repeat;&#13;
#     margin-bottom: 4px;&#13;
#     background-position: 0 4px;&#13;
# }&#13;
# .footerNavContent ul{&#13;
# 	float:left;&#13;
# 	width: 207px;&#13;
#     padding-left: 24px;&#13;
# }&#13;
# .footerCompany h2{&#13;
#     font-size: 10px;&#13;
#     padding-left: 8px;&#13;
#     color: #222;&#13;
#     background-repeat: no-repeat;&#13;
#     margin-bottom: 4px;&#13;
#     background-position: 0 4px;&#13;
# }&#13;
# .footerCompany p{&#13;
# 	font-size: 13px;&#13;
#     color: black;&#13;
#     padding-right: 20px;&#13;
#     font-weight: 700;&#13;
# }&#13;
# &#13;
# .footerCompany p img{&#13;
#     width: 20px;&#13;
#     margin-bottom: -5px;&#13;
#     padding-right: 5px;&#13;
# }&#13;
# .footerCompany ul{&#13;
# 	float:left;&#13;
# 	width: 207px;&#13;
#     padding-left: 24px;&#13;
# }&#13;
# .footericon,.footerrtmart{&#13;
# 	width:500px;&#13;
# 	text-align:left;&#13;
# 	color:#444444;&#13;
# 	padding: 10px 0;&#13;
# }&#13;
# .footericon li,.footerqrcode li{&#13;
# 	float:left;&#13;
# }&#13;
# .footericon li:before{&#13;
# 	content: "";&#13;
#     background-image: url(https://www.rt-mart.com.tw/website/uploads/web_banner/index_social_tiny.png);&#13;
#     background-repeat: no-repeat;&#13;
#     margin: -5px 4px 0 0;&#13;
#     width: 30px;&#13;
#     background-size: 100px 100px;&#13;
#     height: 30px;&#13;
#     vertical-align: middle;&#13;
#     display: inline-block;&#13;
# } &#13;
# &#13;
# .footericon li:nth-child(2):before{&#13;
#     background-position: -30px -66px;&#13;
# } &#13;
# .footericon li:nth-child(3):before{&#13;
#     background-position: -65px 0;&#13;
# } &#13;
# .footerqrcode{&#13;
# 	background-color: #fdfdfd;&#13;
#     padding-top: 10px;&#13;
# 	margin-top: -30px;&#13;
# }&#13;
# .footersocialcontent .codeqr{&#13;
#     width: 180px;&#13;
#     float: right !important;&#13;
# }&#13;
# .footersocialcontent .mobile{&#13;
#     width: 80px;&#13;
#     float: right !important;&#13;
#     padding-bottom: 14px;&#13;
#     border-left: 3px dotted #f1f1f1;&#13;
# }&#13;
# .footersocialcontent .mobile li{&#13;
#     width: 80px;&#13;
#     text-align: center;&#13;
# }&#13;
# .footersocialcontent .codeqr li:nth-child(1) img{&#13;
# 	width:80px;&#13;
# 	height:80px;&#13;
# }&#13;
# .footersocialcontent .codeqr li:nth-child(2) img{&#13;
#     height: 100px;&#13;
#     width: 100px;&#13;
#     margin-top: -10px;&#13;
# }&#13;
# .clear{&#13;
# 	clear:both;&#13;
# }	&#13;
# &#13;
# &#13;
# &#13;
# 	&#13;
# /*電梯floor*/&#13;
# #floorFix{&#13;
# display:block;&#13;
# }&#13;
# &#13;
# #floorFix ul{&#13;
# 	background-color: #ffffff;&#13;
# 	padding-bottom: 60px;&#13;
# }&#13;
# &#13;
# .floorAll{&#13;
#     padding-top: 17px;&#13;
#     position: fixed;&#13;
#     margin-left: 621px;&#13;
#     top: 260px;&#13;
#     left: 45%;&#13;
#     z-index: 9999;&#13;
# }&#13;
# &#13;
# .floor{&#13;
#     background-position: center bottom;&#13;
#     background-repeat: no-repeat;&#13;
#     overflow: hidden;&#13;
#     /*width: 48px;*/&#13;
#     /*border-bottom: 1px solid #a6a6a6;*/&#13;
#     padding-top: 0;&#13;
# }&#13;
# &#13;
# .floor a {&#13;
#     text-decoration: none;&#13;
#     height: 35px;&#13;
#     width: 35px;&#13;
#     line-height: 17px;&#13;
#     background-repeat: no-repeat;&#13;
#     text-decoration: none;&#13;
#     font-size: 14px;&#13;
#     display: block;&#13;
#     text-align: center;&#13;
#     color: #bf0000;&#13;
# 	padding: 1px 0;&#13;
#     background-image: none;&#13;
#     margin:0px auto 4px;&#13;
# }&#13;
# &#13;
# .floor a:hover {&#13;
#     /*background-image: none;*/&#13;
#     /*color: #FFF;*/&#13;
# 	&#13;
# }&#13;
# &#13;
# .floor1 a{&#13;
#     /*background-image: url(https://www.rt-mart.com.tw/direct/uploads/web_banner/glyphiconshalflings-dark.png);*/&#13;
#     background-position: -152px -58px;&#13;
#     background-size: 650px;&#13;
#     color: #738cc2;&#13;
#     border: 1px solid #738cc2;&#13;
# }&#13;
# &#13;
# .floor1 a:hover{&#13;
#     background-color: #738cc2;&#13;
#     color: #fff;&#13;
#     border: 1px solid #fff;&#13;
# }&#13;
# &#13;
# &#13;
# .floor2 a{&#13;
#     /*background-image: url(https://www.rt-mart.com.tw/direct/uploads/web_banner/glyphiconshalflings-dark.png);*/&#13;
#     background-position: -52px -158px;&#13;
#     background-size: 650px;&#13;
#     color: #fa7800;&#13;
#     border: 1px solid #fa7800;&#13;
# }&#13;
# &#13;
# .floor2 a:hover{&#13;
#     background-color: #fa7800;&#13;
#     color: #fff;&#13;
#     border: 1px solid #fff;&#13;
# 	&#13;
# }&#13;
# &#13;
# .floor3 a{&#13;
#     /*background-image: url(https://www.rt-mart.com.tw/direct/uploads/web_banner/glyphiconshalflings-dark.png);*/&#13;
#     background-position: -118px -58px;&#13;
#     background-size: 650px;&#13;
#     color: #a6bf3f;&#13;
#     border: 1px solid #a6bf3f;&#13;
# }&#13;
# &#13;
# .floor3 a:hover{&#13;
#     background-color: #a6bf3f;&#13;
#     color: #fff;&#13;
#     border: 1px solid #fff;&#13;
# }&#13;
# &#13;
# .floor4 a{&#13;
#     /*background-image: url(https://www.rt-mart.com.tw/direct/uploads/web_banner/glyphiconshalflings-dark.png);*/&#13;
#     background-position: 15px -25px;&#13;
#     background-size: 650px;&#13;
#     color: #13ccc7;&#13;
#     border: 1px solid #13ccc7;&#13;
# }&#13;
# &#13;
# .floor4 a:hover{&#13;
#     background-color: #13ccc7;&#13;
#     color: #fff;&#13;
#     border: 1px solid #fff;&#13;
# }&#13;
# &#13;
# &#13;
# .floor5 a{&#13;
#     /*background-image: url(https://www.rt-mart.com.tw/direct/uploads/web_banner/glyphiconshalflings-dark.png);*/&#13;
#     background-position: -118px 8px;&#13;
#     background-size: 650px;&#13;
#     color: #f7986c;&#13;
#     border: 1px solid #f7986c;&#13;
# }&#13;
# &#13;
# .floor5 a:hover{&#13;
#     background-color: #f7986c;&#13;
#     color: #fff;&#13;
#     border: 1px solid #fff;&#13;
# }&#13;
# &#13;
# .floor6 a{&#13;
#     /*background-image: url(https://www.rt-mart.com.tw/direct/uploads/web_banner/glyphiconshalflings-dark.png);*/&#13;
#     background-position: -153px 8px;&#13;
#     background-size: 650px;&#13;
#     color: #e24b42;&#13;
#     border: 1px solid #e24b42;&#13;
# }&#13;
# &#13;
# .floor6 a:hover{&#13;
#     background-color: #e24b42;&#13;
#     color: #fff;&#13;
#     border: 1px solid #fff;&#13;
# }&#13;
# &#13;
# &#13;
# .floor7 a{&#13;
#     /*background-image: url(https://www.rt-mart.com.tw/direct/uploads/web_banner/glyphiconshalflings-dark.png);*/&#13;
#     background-position:-485px -158px;&#13;
#     background-size: 650px;&#13;
# }&#13;
# &#13;
# .floor7 a:hover{&#13;
#     color: #e7374c;&#13;
# 	font-weight:bolder;&#13;
# }&#13;
# &#13;
# .floor8 a{&#13;
#     /*background-image: url(https://www.rt-mart.com.tw/direct/uploads/web_banner/glyphiconshalflings-dark.png);*/&#13;
#     background-position: -219px 8px;&#13;
#     background-size: 650px;&#13;
# 	background-color: #ffddde;&#13;
# }&#13;
# &#13;
# .floor8 a:hover{&#13;
#     color: #fff;&#13;
#     background-color: #f00;&#13;
# }&#13;
# &#13;
# .floor9 a{&#13;
#     /*background-image: url(https://www.rt-mart.com.tw/direct/uploads/web_banner/glyphiconshalflings-dark.png);*/&#13;
#     background-position: -385px -158px;&#13;
#     background-size: 650px;&#13;
# 	color: #888;&#13;
# 	height: 20px;&#13;
# 	padding-top: 5px;&#13;
# }&#13;
# .floor9 a:hover{&#13;
#     /*color: #e7374c;*/&#13;
# }&#13;
# &#13;
# .floor10 a{&#13;
#     background-position:-485px -158px;&#13;
#     background-size: 650px;&#13;
# }&#13;
# &#13;
# .floor10 a:hover{&#13;
#     color: #e7374c;&#13;
#     font-weight:bolder;&#13;
# }&#13;
# &#13;
# /*My客服*/&#13;
# 	#show_srm_outer {&#13;
# 		float: right;&#13;
# 		margin: 0px 0px 0px 0px;&#13;
# 		z-index: 9999;&#13;
# 	}&#13;
# 	&#13;
# 	#show_srm {&#13;
# 		float: right;&#13;
# 		z-index: 9999;&#13;
# 	}&#13;
# 	&#13;
# 	#show_off_button {&#13;
# 		width:40px;height:75px;&#13;
# 		border:0 none;&#13;
# 		border-radius: 10px; &#13;
# 		background-image:url(https://csonline.hotaimotor.com.tw/design/customtheme2/img/tab.png);&#13;
# 		z-index: 9999;&#13;
# 	}&#13;
# 	&#13;
# 	#srm_iframe {&#13;
# 		z-index: 9999;&#13;
# 	}&#13;
# 	&#13;
# 	#floorFix .icon-service {&#13;
# 		content:url(https://contact-center.hithot.cc/rt-mart/design/customtheme2/img/btn_intumit_service.png);&#13;
# 		z-index: 9999;&#13;
# 		width: 48px;&#13;
# 		height: 48px;&#13;
# 	}&#13;
# &#13;
# 	/*2018/02/02 Riley 掛飾*/&#13;
#   /*#cnyStrap04 img,#cnyStrap05 img,#cnyStrap06 img,#cnyStrap07 img{&#13;
#     width: 100%;&#13;
#   }&#13;
# &#13;
#   #cnyStrap04,#cnyStrap05,#cnyStrap06,#cnyStrap07{&#13;
#     display: inline-block;    &#13;
#   }&#13;
# &#13;
#   #cnyStrap04{&#13;
#     position: fixed;&#13;
#     width: 260px;&#13;
#     height: auto;&#13;
#     top: 220px;&#13;
#     right: 45%;&#13;
#     margin-right: 600px;&#13;
#     z-index: 2;&#13;
#   }&#13;
# &#13;
#   #cnyStrap05{&#13;
#     position: fixed;&#13;
#     width: 260px;&#13;
#     height: auto;&#13;
#     top: 220px;&#13;
#     left: 47%;&#13;
#     margin-left: 600px;&#13;
#     z-index: 2;&#13;
#   }&#13;
# &#13;
#   #cnyStrap06{&#13;
#     width: 250px;&#13;
#     height: 500px;&#13;
#     position: absolute;&#13;
#     top: 175px;&#13;
#     left: 0px;&#13;
#     z-index: 1;&#13;
#   }&#13;
# &#13;
#   #cnyStrap07{&#13;
#     width: 200px;&#13;
#     height: 400px;&#13;
#     position: absolute;&#13;
#     top: 175px;&#13;
#     right: 0px;&#13;
#     z-index: 1;&#13;
#   }&#13;
# &#13;
#   @media screen and (max-width: 1700px) {&#13;
#     #cnyStrap06,#cnyStrap07{&#13;
#       display: none;&#13;
#   }*/&#13;
# &#13;
# &#13;
# 		&#13;
# </style>&#13;
# &#13;
# <!-- 20170128 END	-->&#13;
# <!---->&#13;
# <body id="">&#13;
# &#13;
# <div>&#13;
#   <div class="FOR_TOP">&#13;
# <!---->&#13;
# 	    &#13;
# <script language="javascript">&#13;
# //&lt;![CDATA[&#13;
#     /*熱門關鍵字*/&#13;
#     function hot_keyword(name)&#13;
#     {&#13;
#         $("#prod_keyword").val(name);&#13;
#         document.topForm.submit();&#13;
#     }&#13;
#     /*熱門關鍵字END*/&#13;
# &#13;
#     /*url*/&#13;
#     $(document).ready(function(){&#13;
#       $("#btn_submit").click(function(){&#13;
#             $("[name='topForm']").attr("action","index.php?action=prod_search&amp;prod_keyword="+$("[name='prod_keyword']").val());&#13;
#         });&#13;
#     });&#13;
#     /*url end*/&#13;
# &#13;
#     /*抓購物車商品圖片*/&#13;
#     function getProdImg(uid)&#13;
#     {&#13;
#         var _return;&#13;
#         $.ajax({&#13;
#             url : "/direct/api/api.shopping_cart.php",&#13;
#             type : "POST",&#13;
#             data : {&#13;
#                 myAct : "getProdImg",&#13;
#                 uid : uid&#13;
#             },&#13;
#             async:false,&#13;
#             success : function(data)&#13;
#             {&#13;
#                 _return = data;&#13;
#             }&#13;
#         });&#13;
#         return _return;&#13;
#     }&#13;
#     /*抓購物車商品圖片 END*/&#13;
#     /*移除購物車商品*/&#13;
#     function it45_removeScar( uid ){&#13;
#         $.ajax({&#13;
#             url : "/direct/api/api.shopping_cart.php",&#13;
#             type : "POST",&#13;
#             data : {&#13;
#                 myAct : "removeScarByUid",&#13;
#                 uid : uid&#13;
#             },&#13;
#             success : function(data)&#13;
#             {&#13;
#                 top_refresh();&#13;
#             }&#13;
#         });&#13;
#     }&#13;
#     /*移除購物車商品END*/&#13;
# &#13;
#     function _topFormCheck(_this) {&#13;
#         if (_this.prod_keyword.value == "") {&#13;
#             alert('請輸入關鍵字！');//請輸入關鍵字！&#13;
#             return false;&#13;
#         }&#13;
#     }&#13;
#     String.prototype.trim = function() {&#13;
#         return this.replace(/(^\s*)|(\s*$)/g, "");&#13;
#     }&#13;
#     function formatNumber(str) {&#13;
#         str = str.trim();&#13;
# &#13;
#         if (str.length &lt;= 3) {&#13;
#             return str;&#13;
#         } else {&#13;
#             return formatNumber(str.substr(0, str.length - 3)) + ','&#13;
#                     + str.substr(str.length - 3);&#13;
#         }&#13;
#     }&#13;
#     var top_scar_no = 0;&#13;
# &#13;
#     function getCookie(name) {&#13;
#         var nameEQ = name + "=";&#13;
#         var ca = document.cookie.split(';');&#13;
#         for ( var i = 0; i &lt; ca.length; i++) {&#13;
#             var c = ca[i];&#13;
#             while (c.charAt(0) == ' ')&#13;
#                 c = c.substring(1, c.length);&#13;
#             if (c.indexOf(nameEQ) == 0)&#13;
#                 return c.substring(nameEQ.length, c.length);&#13;
#         }&#13;
#         return null;&#13;
#     }&#13;
# &#13;
#     function top_refresh() {&#13;
#         var _scar_no = "";&#13;
#         if (_scar_no == '') {&#13;
#             _scar_no = getCookie('scar_no_' + $(location).attr('href').split('/')[3]);&#13;
# &#13;
#         }&#13;
#         $.ajax({&#13;
#                     url : "/direct/api/api.shopping_cart.php",&#13;
#                     type : "POST",&#13;
#                     dataType : "json",&#13;
#                     data : {&#13;
#                         myAct : "getCartNumber",&#13;
#                         scar_no : _scar_no,&#13;
#                         nti_JUFBJUI3JUJDJUFFJUI5JTdDJTdCJUJDeSVBQnklQkMlODElQTklQjclODElQjclQjglN0MlQjMlN0QlQjQlODElQkElQkQlN0M : "MTU4MzgyNTY5MjYwVG12NUhlc0k3ZmpiY2FjT0MyZUx0cXhxUkpzZ2Nj"&#13;
#                     },&#13;
#                     success : function(Jdata) {&#13;
#                         if (Jdata.error == 'C00') {&#13;
#                             $('#top_scar_no').html(Jdata.count);&#13;
#                             $('#top_scar_no2').html(Jdata.count);&#13;
#                             $('#sideCart3').empty();&#13;
#                             var html = "";&#13;
#                             var top_sum = 0;&#13;
#                             $.each(&#13;
#                                             Jdata.content,&#13;
#                                             function(key, value) {&#13;
#                                                 //var subsum = parseInt(value['prod_selling_price'])*parseInt(value['scar_count']);&#13;
#                                                 var top_str = "";&#13;
#                                                 if (value['scar_type'] == 1)&#13;
#                                                     top_str = "(加贈)";&#13;
#                                                 if (value['scar_type'] == 2)&#13;
#                                                     top_str = "(加購)";&#13;
#                                                 var top_size = " ("&#13;
#                                                         + value['prod_color_name']&#13;
#                                                         + value['prod_size']&#13;
#                                                         + ") ";&#13;
#                                                 var val = 'https://www.rt-mart.com.tw/website/uploads_product/' + value['prod_file'];&#13;
#                                                 //getProdImg(value['prod_uid']);&#13;
#                                                 html += '&lt;ul class="pro"&gt;';&#13;
#                                                 html += '&lt;li class="pro_img"&gt;';&#13;
#                                                 html += '&lt;a href="/direct/index.php?action=product_detail&amp;prod_no='&#13;
#                                                         + value['prod_no']&#13;
#                                                         + '"&gt;';&#13;
#                                                 html += '&lt;img src="' + val + '" title="' + value['prod_name'] + '" alt="' + value['prod_name'] + '" width="45" height="45" /&gt;';&#13;
#                                                 html += '&lt;/a&gt;';&#13;
#                                                 html += '&lt;/li&gt;';&#13;
#                                                 html += '&lt;li class="pro_name"&gt;';&#13;
#                                                 html += '&lt;h5&gt;';&#13;
#                                                 html += '&lt;a href="/direct/index.php?action=product_detail&amp;prod_no='&#13;
#                                                         + value['prod_no']&#13;
#                                                         + '"&gt;' + value['prod_name'] + '&lt;/a&gt;';&#13;
#                                                 html += '&lt;/h5&gt;';&#13;
#                                                 html += '&lt;div class="price"&gt;$' + value['scar_price'] + '&lt;span&gt;X' + value['scar_count'] + '&lt;/span&gt;&lt;/div&gt;';&#13;
#                                                 html += '&lt;/li&gt;';&#13;
#                                                 html += '&lt;li class="pro_del"&gt;&lt;a href="javascript: it45_removeScar(\'' + value['uid'] + '\');"&gt;刪除&lt;/a&gt;&lt;/li&gt;';&#13;
#                                                 html += '&lt;/ul&gt;';&#13;
# &#13;
#                                                 top_sum += value['scar_price'] * value['scar_count'];&#13;
#                                             });&#13;
#                             if(top_sum &gt; 0){&#13;
#                                 html += '&lt;div class="checkout"&gt;';&#13;
#                                 html += '&lt;div class="price"&gt;總計&lt;!--總計--&gt;：&lt;span&gt;$' + top_sum + '&lt;/span&gt;&lt;/div&gt;';&#13;
#                                 html += '&lt;div class="cart"&gt;&lt;a href="/direct/index.php?action=shopping_cart&amp;web_cart_myAct=SHOPPING_CART"&gt;結帳&lt;/a&gt;&lt;/div&gt;';&#13;
#                                 html += '&lt;/div&gt;';&#13;
#                             }&#13;
#                             $('#sideCart3').append(html);&#13;
#                         }&#13;
#                     }&#13;
#                 })&#13;
#         $(".formatNumber").each(function(i) {&#13;
#             var _num = $(this).html();&#13;
#             $(this).html(formatNumber(_num));&#13;
#         })&#13;
#     }&#13;
#     jQuery(document).ready(function($) {&#13;
#         top_refresh();&#13;
#     })&#13;
# &#13;
# &#13;
#     // 捲軸滑動固定搜尋列&#13;
#     $(function(){&#13;
#     $left_nav = $(".left_nav"),&#13;
#     $search = $(".search"),&#13;
#     $body = $(document),&#13;
#     $win = $(window);&#13;
# &#13;
#         window.goTopMove = function () {&#13;
#             var scrollH = $body.scrollTop();&#13;
# &#13;
#                 if(scrollH &gt; 50) {&#13;
# &#13;
#                     $left_nav.stop().css({"display":"none"});&#13;
#                     $search.stop().css({"position":"fixed","top":"0px","right":"unset","z-index":"9999","margin-left":"56px"});&#13;
#                     $(".hamburger").stop().css({"display":"unset"});&#13;
#                     $("#rtLogo a").stop().css({"display":"inline-block"});&#13;
# &#13;
#                 }else{&#13;
#                 &#13;
#                     $left_nav.stop().css({"display":"block"});&#13;
#                     $search.stop().css({"position":"absolute","top":"40px","right":"0px","z-index":"unset","margin-left":"unset"});&#13;
#                     $(".hamburger").stop().css({"display":"none"});&#13;
#                     $("#rtLogo a").stop().css({"display":"none"});&#13;
#                 }&#13;
#         };  &#13;
#         $win.on({&#13;
#             scroll: function() {goTopMove();},&#13;
#             resize: function() {goTopMove();}&#13;
#         });&#13;
# &#13;
#         $(".hamburger").on("click",function(){&#13;
#             $(".rtmartHEADER02").hasClass("segmentFixed")? $(".rtmartHEADER02").removeClass("segmentFixed"):$(".rtmartHEADER02").addClass("segmentFixed");&#13;
#             $(".hamburger").hasClass("hamburgerFixed")? $(".hamburger").removeClass("hamburgerFixed"):$(".hamburger").addClass("hamburgerFixed");&#13;
#         });&#13;
# &#13;
#     });&#13;
# &#13;
# //]]&gt;&#13;
# </script>&#13;
# <style>&#13;
# #sideBar1{&#13;
# 	position: fixed;&#13;
#     right: 0px;&#13;
#     top: 290px;&#13;
#     padding: 5px 0;&#13;
#     width: 23px;&#13;
#     z-index: 110;&#13;
#     border-bottom-left-radius: 8px;&#13;
#     border-top-left-radius: 8px;&#13;
#     background: #FF9800;&#13;
#     cursor: pointer;&#13;
# 	}&#13;
# #nps{&#13;
# 	color: white;&#13;
#     text-decoration: none;&#13;
#     display: block;&#13;
#     text-align: center;&#13;
# 	}	&#13;
# &#13;
# &#13;
# </style>&#13;
# &#13;
# <style type="text/css">&#13;
# #rtLogo a{&#13;
#     display: none;&#13;
#     width: 27px;&#13;
#     height: 27px;&#13;
#     background: url(https://www.rt-mart.com.tw/website/uploads/web_banner/rtmart_icon.png) no-repeat 0 0;&#13;
#     position: absolute;&#13;
#     left: 0;&#13;
#     z-index: 999;&#13;
# }&#13;
# &#13;
# .hamburger{&#13;
#     display: none;&#13;
#     width: 25px;&#13;
#     height: 25px;&#13;
#     float: right;&#13;
#     border-radius: 5px;&#13;
#     padding: 2px;&#13;
#     margin: 1px 2px;&#13;
#     background-color: rgba(0,0,0,.5);&#13;
#     box-sizing: border-box;&#13;
#     position: absolute;&#13;
#     left: 27px;&#13;
#     z-index: 999;&#13;
# }&#13;
# &#13;
# .hamburger span{&#13;
#     display: block;&#13;
#     width: 80%;&#13;
#     height: 3px;&#13;
#     margin: 3px 2px;&#13;
#     background-color: rgba(255,255,255,.9);&#13;
# }&#13;
# &#13;
# .hamburgerFixed #bar2{&#13;
#     display: none;&#13;
# }&#13;
# &#13;
# .hamburgerFixed #bar1{&#13;
#     transform: rotateZ(45deg);&#13;
#     position: absolute;&#13;
#     top: 8px;&#13;
#     left: 1px;&#13;
# }&#13;
# &#13;
# .hamburgerFixed #bar3{&#13;
#     transform: rotateZ(-45deg);&#13;
#     position: absolute;&#13;
#     bottom: 8px;&#13;
#     left: 1px;&#13;
# }&#13;
# &#13;
# .segmentFixed{&#13;
#     position: fixed;&#13;
#     top: 27px;&#13;
#     z-index: 999;&#13;
# }&#13;
# </style>&#13;
# &#13;
#     <div id="sideBar">&#13;
#     <img class="view_cart" src="https://www.rt-mart.com.tw/direct/templates/web_style/rtmart/color_1/zh-tw/images/common/cart_rightlist.png" width="28" height="99" />&#13;
#         <ul>&#13;
#             <li class="shoppingList"><a href="javascript:void(0);">購物清單<!--購物清單--></a></li>&#13;
#             <li>購物車<!--購物車--><br />&#13;
#             <span id="top_scar_no2"></span>件商品<!--件商品--><br />&#13;
#             <!--總計:<span class="formatNumber" id="top_sum2"></span></li>-->&#13;
#             </li><li class="go"><a href="/direct/index.php?action=shopping_cart"></a></li>&#13;
#         </ul>&#13;
#     </div>&#13;
# &#13;
#     <!-- 版頭 -->&#13;
#     <!-- 上方導覽 -->&#13;
# &#13;
#     <div class="topfixed">&#13;
#     <div class="topnav">&#13;
#         <div id="rtLogo">&#13;
#             <a href="https://www.rt-mart.com.tw/direct/"><!---->&#13;
#             </a>&#13;
#         </div>&#13;
#         <div class="hamburger">&#13;
#             <span id="bar1"></span>&#13;
#             <span id="bar2"></span>&#13;
#             <span id="bar3"></span>&#13;
#         </div>&#13;
#     <ul class="left_nav" style="white-space: nowrap">&#13;
# &#13;
#     <!--	<li class="home"><a href="http://www.rt-mart.com.tw/direct/index.php?action=hyperstore">大潤發官網	--><!----><!--	</a></li>	-->&#13;
#     <li class="home"><a href="https://news.rt-mart.com.tw/main">大潤發官網<!----></a></li>&#13;
#     <ul class="drop-down-menu">&#13;
# <li class="store06"><a class="now" href="/">網路宅配<!----></a></li>&#13;
# <li class="store999"><a class="now" href="#">到店取貨</a><!---->&#13;
# &#13;
#             <ul>&#13;
#                 <li><a class="now" href="#">北   部</a>&#13;
#                     <ul>&#13;
#                         <li class="store999"><a class="now" href="/nh2/">台北內湖2店<!--台北內湖2店--></a></li>&#13;
#                         <li class="store999"><a class="now" href="/bitan/">新北碧潭店<!--新北碧潭店--></a></li>&#13;
#                         <li class="store999"><a class="now" href="/tucheng/">新北土城店<!--新北土城店--></a></li>&#13;
#                     </ul>&#13;
#                 </li>&#13;
#                  <li><a class="now" href="#">桃竹苗</a>&#13;
#                     <ul>&#13;
# 			<li class="store999"><a class="now" href="/pingchen/">桃園平鎮店<!--桃園平鎮店--></a></li>&#13;
#                         <li class="store999"><a class="now" href="/zhongxiao/">新竹忠孝店<!--新竹忠孝店--></a></li>&#13;
# 			<li class="store999"><a class="now" href="/toufen/">苗栗頭份店<!--Toufen Store--></a></li>&#13;
#                     </ul>   &#13;
#                 </li>&#13;
#                  <li><a class="now" href="#">南   部</a>&#13;
#                     <ul>&#13;
#                         <li class="store999"><a class="now" href="/tainan/">台南店<!--台南店--></a></li>&#13;
#                		 <li class="store999"><a class="now" href="/fongshan/">高雄鳳山店<!--高雄鳳山店--></a></li>&#13;
# 		 </ul>&#13;
#                 </li>&#13;
#                  <li><a class="now" href="#">東   部</a>&#13;
#                     <ul>&#13;
#                         <li class="store999"><a class="now" href="/taitung/">台東店<!--台東店--></a></li>&#13;
#                     </ul>&#13;
#                 </li>&#13;
#             </ul>&#13;
# </li>&#13;
# <!--20170421 ADD 全省店鋪-->&#13;
# <li class="store913"><a class="now" href="#">各店活動</a><!---->&#13;
# &#13;
#             <ul>&#13;
#                 <li><a class="now" href="#">北   部</a>&#13;
#                     <ul>&#13;
#                        <!-- <li class="store913"><a class="now" href="/nh1/">台北內湖1店內湖1店</a></li>-->&#13;
#                         <li class="store913"><a class="now" href="/nh2/">台北內湖2店<!--台北內湖2店--></a></li>&#13;
#                         <li class="store913"><a class="now" href="/jingpin/">台北景平店<!--景平--></a></li>&#13;
#                         <li class="store913"><a class="now" href="/citylink/">台北中崙店<!--中崙--></a></li>&#13;
#                         <li class="store913"><a class="now" href="/bitan/">新北碧潭店<!--新北碧潭店--></a></li>&#13;
#                         <li class="store913"><a class="now" href="/tucheng/">新北土城店<!--新北土城店--></a></li>&#13;
#                         <li class="store913"><a class="now" href="/chungho/">新北中和店<!--中和--></a></li>&#13;
#                     </ul>&#13;
#                 </li>&#13;
#                  <li><a class="now" href="#">桃竹苗</a>&#13;
#                     <ul>&#13;
#             <li class="store913"><a class="now" href="/pingchen/">桃園平鎮店<!--桃園平鎮店--></a></li>&#13;
#             <li class="store913"><a class="now" href="/chungli/">桃園中壢店<!--中壢--></a></li>&#13;
#             <li class="store913"><a class="now" href="/bade/">桃園八德店<!--八德--></a></li>&#13;
#             <li class="store913"><a class="now" href="/zhongxiao/">新竹忠孝店<!--新竹忠孝店--></a></li>&#13;
#              <li class="store913"><a class="now" href="/nanya/">新竹湳雅店<!--湳雅--></a></li>&#13;
#             <li class="store913"><a class="now" href="/toufen/">苗栗頭份店<!--Toufen Store--></a></li>         &#13;
#                     </ul>   &#13;
#                 </li>&#13;
#                 <li><a class="now" href="#">中   部</a>&#13;
#                     <ul> &#13;
#                      <li class="store913"><a class="now" href="/chungming/">台中忠明店<!--忠明--></a></li>&#13;
#                      <li class="store913"><a class="now" href="/yuanlin/">彰化員林店<!--員林--></a></li>&#13;
#                      <li class="store913"><a class="now" href="/tounan/">雲林斗南店<!--斗南--></a></li>&#13;
#                     </ul>&#13;
#                 </li>&#13;
#                  <li><a class="now" href="#">南   部</a>&#13;
#                     <ul>&#13;
#                      <li class="store913"><a class="now" href="/chiayi/">嘉義店<!--嘉義--></a></li>&#13;
#                      <li class="store913"><a class="now" href="/tainan/">台南店<!--台南店--></a></li>&#13;
#                      <!--<li class="store998"><a class="now" href="/anping/">台南安平店安平</a></li>-->&#13;
#                      <li class="store913"><a class="now" href="/chiali/">台南佳里店<!--佳里--></a></li>&#13;
#                      <li class="store913"><a class="now" href="/fongshan/">高雄鳳山店<!--高雄鳳山店--></a></li>&#13;
#          </ul>&#13;
#                 </li>&#13;
#                  <li><a class="now" href="#">東   部</a>&#13;
#                     <ul>&#13;
#                         <li class="store913"><a class="now" href="/taitung/">台東店<!--台東店--></a></li>&#13;
#                     </ul>&#13;
#                 </li>&#13;
#             </ul>&#13;
# </li>&#13;
# 	<li class="store88"><a class="now" href="/tatsung/">商業用戶<!----></a></li>&#13;
# </ul>&#13;
#     <!--<li class="store02"><a class="now" href="/zhongxiao/">新竹忠孝店<!----><!--<a class="hover" href="/zhongxiao/">到店取貨<!--</a></li>
#     <li class="store05"><a class="now" href="/bitan/">新北碧潭店<!----><!--<a class="hover" href="/bitan/">到店取貨<!--</a></li>
#     <li class="store03"><a href="/china/">大陸館</a></li>
#     <li class="store04"><a href="/love/">愛心專館</a></li>-->&#13;
#     </ul>&#13;
#     <ul class="right_nav">&#13;
#     <li class="lan01">  <a href="https://www.rt-mart.com.tw/member/index.php?action=member_login&amp;r_byeurl=direct">登入</a> </li>&#13;
#     <!--li class="fb"><a href="https://www.facebook.com/rtmart888">大潤發粉絲團</a></li-->&#13;
#     <!--	<li class="lan01"><a href="http://line.me/ti/p/%40bvq0787c"  style="background:#00c300;color:white;">Line@好友</a></li>	-->&#13;
#     <li class="lan01"><a href="https://www.rt-mart.com.tw/member/index.php?action=account" style="background:#3b5998;color:white;">會員中心</a></li>&#13;
#     <li class="lan01"><a href="https://www.rt-mart.com.tw/direct/index.php?action=linejoin" style="background:#00c300;color:white;">Line</a></li>&#13;
#     <li class="shoppingcart"><a href="/direct/index.php?action=shopping_cart&amp;web_cart_myAct=SHOPPING_CART" class="cart">購物車<!----><span class="num" id="top_scar_no"></span>件<img class="arrow" src="https://www.rt-mart.com.tw/direct/templates/web_style/rtmart/color_1/zh-tw/rtmart_arrowicon.png" width="7" height="4" /></a>&#13;
#     <!-- 購物車商品 -->&#13;
#     <div id="sideCart3">&#13;
#         <!-- 商品 HTML -->&#13;
#     </div>&#13;
#     <!-- 購物車商品end -->&#13;
# &#13;
#     <!-- 購物車商品 -->&#13;
#     <div id="sideCart2" style="display:none;">&#13;
#         <!-- 商品 -->&#13;
#         <ul class="pro">&#13;
#             <li class="pro_img"><a href="#"><img src="" width="45" height="45" /></a></li>&#13;
#             <li class="top_title_show">&#13;
#                 <!--<h5><a href="#"></a></h5>
#                 <div class="price">$180<span>X1</span></div>-->&#13;
#             </li>&#13;
#             <li class="pro_del"></li>&#13;
#         </ul>&#13;
#         <!-- 商品end -->&#13;
#     </div>&#13;
#     <!-- 購物車商品end -->&#13;
#     </li>&#13;
#     </ul>&#13;
#     </div>&#13;
#     </div>&#13;
#     <!-- 上方導覽end -->&#13;
# &#13;
#     <div class="rtmartHEADER">&#13;
#     <!-- logo/banner/搜尋 -->&#13;
#     <div class="tophead">&#13;
#     <h1 class="logo">&#13;
# 	<!-- 20170420	-->&#13;
# 	    <a href="https://www.rt-mart.com.tw/direct/"><img src="https://www.rt-mart.com.tw/website/uploads/website_2/zh-tw/logo.png" alt="大潤發網路購物中心 回首頁" width="260" height="80" border="0" title="大潤發網路購物中心 回首頁" /></a>&#13;
# 		&#13;
# 	    </h1>&#13;
#     <div class="banner">&#13;
# 	&#13;
# 	<a href="" target="_blank" alt=""></a></div>&#13;
#     	<!--a href="http://www.rt-mart.com.tw/member/index.php?action=intro_delivery" target="" alt="" style="position: absolute;margin-left: 260px;"><img src="http://www.rt-mart.com.tw/website/uploads/web_banner/freeshipping.jpg" id="top_banner.jpg" alt="大潤發購物中心" title="大潤發購物中心" border="0" width="195" height="80"></a-->&#13;
# 	&#13;
# 			&#13;
# 	<!--熱門關鍵字-->&#13;
#     <ul class="search_keyword">&#13;
#         <li class="for_keywords">&#13;
#                             <a href="javascript: hot_keyword('');"></a>&#13;
#                     </li>&#13;
#     </ul>&#13;
#     <!--熱門關鍵字END-->&#13;
#     <form name="topForm" onsubmit="return _topFormCheck(this);" method="post" action="index.php?action=prod_search" id="topForm">&#13;
#     <ul class="search">&#13;
#     <li class="for_list">&#13;
#     <select name="">&#13;
#       <option>全館商品<!----></option>&#13;
#       <!--<option>特惠商品</option>-->&#13;
#     </select>&#13;
#     </li>&#13;
#     <li class="for_indexinput"><input name="prod_keyword" id="product_keyword" type="text" title="Search" value="" /></li>&#13;
#     <li class="for_btn"><input name="btn_submit" type="submit" id="btn_submit" value="" /></li>&#13;
#     <li class="for_moresearch"><a href="/direct/index.php?action=product_search_plus">進階搜尋<!---->&gt;</a></li>&#13;
#     </ul>&#13;
#     </form>&#13;
#     </div>&#13;
#     <!-- logo/banner/搜尋end -->&#13;
#     </div>&#13;
#     <div class="rtmartHEADER02 clearFix">&#13;
#     <!--20140108主選單-->&#13;
#         <ul class="main_nav">&#13;
#             <!--次選單-->&#13;
#                         <li class="nav01">&#13;
#                                 <a href="http://www.rt-mart.com.tw/direct/index.php?action=newimport&amp;utm_source=rtmart&amp;utm_medium=referral&amp;utm_campaign=newimport">進口食品</a>&#13;
#                                 <div class="sub_nav">&#13;
#                     <div class="left_box">&#13;
#                                                 <div class="list_box">&#13;
#                             <h4><a href="index.php?action=product_sort&amp;prod_sort_uid=3869">義大利</a></h4>&#13;
#                                 <ul>&#13;
#                                                                     <li><a href="index.php?action=product_sort&amp;prod_sort_uid=24347">氣泡礦泉水</a></li>&#13;
#                                                                     <li><a href="index.php?action=product_sort&amp;prod_sort_uid=24308">橄欖油／其他食用油</a></li>&#13;
#                                                                     <li><a href="index.php?action=product_sort&amp;prod_sort_uid=14341">咖啡粉/咖啡豆</a></li>&#13;
#                                                                     <li><a href="index.php?action=product_sort&amp;prod_sort_uid=14351">義大利麵條</a></li>&#13;
#                                                                     <li><a href="index.php?action=product_sort&amp;prod_sort_uid=54367">純番茄罐頭/醬</a></li>&#13;
#                                                                     <li><a href="index.php?action=product_sort&amp;prod_sort_uid=54411">鹹食醬料</a></li>&#13;
#                                                                     <li><a href="index.php?action=product_sort&amp;prod_sort_uid=14361">醃製蔬菜/肉類罐頭</a></li>&#13;
#                                                                     <li><a href="index.php?action=product_sort&amp;prod_sort_uid=54323">甜餅乾</a></li>&#13;
#                                                                     <li><a href="index.php?action=product_sort&amp;prod_sort_uid=54345">鹹餅乾</a></li>&#13;
#                                                                 </ul>&#13;
#                         </div>&#13;
#                                                 <div class="list_box">&#13;
#                             <h4><a href="index.php?action=product_sort&amp;prod_sort_uid=3870"><img src="https://www.rt-mart.com.tw/website/uploads/web_banner/cataflag/flag_france2.png" style="margin-top: 5px;" />法國</a></h4>&#13;
#                                 <ul>&#13;
#                                                                     <li><a href="index.php?action=product_sort&amp;prod_sort_uid=14151">糖餅／巧克力</a></li>&#13;
#                                                                     <li><a href="index.php?action=product_sort&amp;prod_sort_uid=14141">飲料／礦泉水</a></li>&#13;
#                                                                 </ul>&#13;
#                         </div>&#13;
#                                                 <div class="list_box">&#13;
#                             <h4><a href="index.php?action=product_sort&amp;prod_sort_uid=3878">亞洲進口食品</a></h4>&#13;
#                                 <ul>&#13;
#                                                                     <li><a href="index.php?action=product_sort&amp;prod_sort_uid=24360">餅乾／糖果／巧克力</a></li>&#13;
# ...
# 				</ul>&#13;
# 				<ul class="footerrtmart">&#13;
# 					<li>&#13;
# 						客戶免費專線：0800-010-020(周一至周日 8:00-22:00 )</li>&#13;
# 				</ul>&#13;
# 				<ul class="footerqrcode mobile">&#13;
# 					<li>&#13;
# 						<a href="/direct/index.php?forceDevice=mobile" title="大潤發手機板"><img alt="大潤發宅配手機板" src="https://www.rt-mart.com.tw/website/uploads/web_banner/mobile_icon1.png" /><br />&#13;
# 						宅配到府<br />&#13;
# 						手機版</a></li>&#13;
# 				</ul>&#13;
# 				<ul class="footerqrcode codeqr">&#13;
# 					<li>&#13;
# 						<a href="https://contact-center.hithot.cc/rt-mart/index.php?eservice=qrcode&amp;qaCategory=general" title="my客服"><img alt="my客服" height="80px" src="https://www.rt-mart.com.tw/website/uploads/web_banner/MyQR.png" width="80px" /></a></li>&#13;
# 					<li>&#13;
# 						<a href="https://line.me/R/ti/p/%40066njrba?utm_source=rtmart&amp;utm_medium=belt3a&amp;utm_campaign=linejoin" title="LineAt"><img alt="LineAt" src="https://www.rt-mart.com.tw/website/uploads/fckeditor/direct/image/line(1).jpg" style="width: 100px; height: 100px;" /></a></li>&#13;
# 				</ul>&#13;
# 			</div>&#13;
# 		</div>&#13;
# 	</div>&#13;
# 	<div id="footerbottom">&#13;
# 		<p>&#13;
# 			建議使用Chrome瀏覽器以達最佳瀏覽體驗</p>&#13;
# 		<p>&#13;
# 			大潤發流通事業版權所有©2013 RT-MART All Rights Reserved.</p>&#13;
# 	</div>&#13;
# </div>&#13;
#   &#13;
#     </div> &#13;
# &#13;
# <!---->&#13;
# <script language="javascript" type="text/javascript" src="https://www.rt-mart.com.tw/direct/javascripts/ij-ajax/_ij_package.js"></script>&#13;
# <script language="javascript" type="text/javascript" src="https://www.rt-mart.com.tw/direct/javascripts/dojo-ajax/dojo.js"></script>&#13;
# <script src="https://www.rt-mart.com.tw/direct/javascripts/jquery/jquery-1.9.1.min.js"></script>&#13;
# <script language="javascript">&#13;
# function _openPageEditContent( _wpitem_uid )&#13;
# {&#13;
# 	var open_uri = 'https://www.rt-mart.com.tw/direct/admweb/admweb.main.php?action=website_page_item_content' + &#13;
# 					'&amp;wpitem_uid=' + _wpitem_uid;&#13;
# 		&#13;
# 	var oOpenWindow = window.open(open_uri,&#13;
# 								'page_item_content',&#13;
# 								'toolbar=no,location=no,directories=no,status=no,menubar=no,scrollbars=yes,resizable=yes,copyhistory=no,width=780,height=580');&#13;
# 	oOpenWindow.focus();&#13;
# }&#13;
# &#13;
# function _openPageEditWindow( open_uri )&#13;
# {&#13;
# 	var oOpenWindow = window.open(open_uri,&#13;
# 								'page_edit',&#13;
# 								'toolbar=no,location=no,directories=no,status=no,menubar=no,scrollbars=yes,resizable=yes,copyhistory=no,width=780,height=580');&#13;
# 	oOpenWindow.focus();&#13;
# }&#13;
# &#13;
# function _openImage( imgUri, imgPath ,imagewidth ,imageheight)&#13;
# {&#13;
# 	imagewidth = imagewidth || 400; &#13;
# 	imageheight = imageheight || 400; &#13;
# 	if( !imgPath ) imgPath = '';&#13;
# 	var open_uri = 'https://www.rt-mart.com.tw/direct/openwin/openwin.index.php?action=images' + &#13;
# 					'&amp;imgUri=' + imgUri +&#13;
# 					'&amp;imgPath=' + imgPath;&#13;
# &#13;
# 	var oOpenWindow = window.open(open_uri,&#13;
# 								'openImage',&#13;
# 								'toolbar=no,location=no,directories=no,status=no,menubar=no,scrollbars=no,resizable=yes,copyhistory=no,width='+imagewidth+',height='+imageheight );&#13;
# 	oOpenWindow.focus();&#13;
# }&#13;
# &#13;
# function _openProductSort( jsAct, formName, elName, lang, _args )&#13;
# {&#13;
# 	var open_uri = 'https://www.rt-mart.com.tw/direct/openwin/openwin.index.php?action=product_sort' + &#13;
# 					'&amp;jsAct=' + jsAct +&#13;
# 					'&amp;form_name=' + formName +&#13;
# 					'&amp;el_name=' + elName +&#13;
# 					'&amp;openwin_lang=' + lang;&#13;
# 	if(_args)&#13;
# 		open_uri += _args;&#13;
# 	&#13;
# 	var oOpenWindow = window.open(open_uri,&#13;
# 								'productSort',&#13;
# 								'toolbar=no,location=no,directories=no,status=no,menubar=no,scrollbars=yes,resizable=yes,copyhistory=no,width=600,height=300');&#13;
# 	oOpenWindow.focus();&#13;
# }&#13;
# &#13;
# function _reloadAuthimgImg( imgId )&#13;
# {&#13;
# 	var r = Math.round(Math.random()*9999);&#13;
# 	document.getElementById( imgId ).src = 'https://www.rt-mart.com.tw/direct/images/authimg.php?' + r;&#13;
# }&#13;
# &#13;
# /**/&#13;
# //var menu_move_x = 0; /**/&#13;
# //var menu_move_y = 0; /**/&#13;
# var menuDivId;&#13;
# var menuDivId_out;&#13;
# var objMenuDiv;&#13;
# var objMenuDiv_out;&#13;
# var _isMenuDiv = 0;&#13;
# &#13;
# function showWebMenu( id ){&#13;
# 	menuDivId = 'div_webMenu_' + id;&#13;
# 	_isMenuDiv = 1;&#13;
# &#13;
# 	objMenu = document.getElementById( 'webMenu_' + id );&#13;
# 	objMenuDiv = document.getElementById( menuDivId );&#13;
# &#13;
# 	if( objMenuDiv ){&#13;
# 		graphics = ij_getXY(objMenu);&#13;
# 		&#13;
# 		objMenuDiv.style.left = graphics[0] + menu_move_x + 'px';&#13;
# 		objMenuDiv.style.top = graphics[1] + menu_move_y + 'px';	&#13;
# 		&#13;
# 		ij_showDiv(menuDivId, true);&#13;
# 	}&#13;
# 	&#13;
# 	if( objMenuDiv_out &amp;&amp; menuDivId_out != menuDivId ){&#13;
# 		ij_showDiv(menuDivId_out, false);&#13;
# 	}&#13;
# 	menuDivId_out = null;&#13;
# }&#13;
# &#13;
# function removeWebMenu( id, timeOut ){&#13;
# 	menuDivId_out = 'div_webMenu_' + id;&#13;
# 	objMenuDiv_out = document.getElementById( 'div_webMenu_' + id );&#13;
# 	&#13;
# 	_isMenuDiv = 0;&#13;
# 	setTimeout( '_removeWebMenu()' ,timeOut);&#13;
# }&#13;
# &#13;
# function _removeWebMenu(){&#13;
# 	if( !_isMenuDiv &amp;&amp; objMenuDiv_out )&#13;
# 		ij_showDiv(menuDivId_out, false);&#13;
# }&#13;
# /**/&#13;
# &#13;
# String.prototype.trim = function() { return this.replace(/(^\s*)|(\s*$)/g, ""); }&#13;
# function formatNumber(str) {&#13;
#     str = str.trim();&#13;
#     if(str.length &lt;= 3){&#13;
#         return str;&#13;
#     }else{&#13;
#         return formatNumber(str.substr(0,str.length-3))+','+str.substr(str.length-3);&#13;
#     }&#13;
# }&#13;
# function RemoveStringComma(number) {&#13;
#     var pos = number.indexOf(",");&#13;
#     while (pos != -1) {&#13;
#         number = number.substring(0, pos) + number.substring(pos + 1, number.length);&#13;
#         pos = number.indexOf(",");&#13;
#     }&#13;
#     return number;&#13;
# }&#13;
# jquery = jQuery.noConflict(true);&#13;
# jquery(document).ready(function($){&#13;
#     //$(".formatNumber").find("font").each(function(i){&#13;
# 	//$(".formatNumber").each(function(i){&#13;
#     //    var _num = $(this).html();&#13;
#     //    $(this).html(formatNumber(_num));&#13;
#     //})&#13;
# &#13;
#     $("textarea").keyup(function(event){&#13;
# &#13;
#         var test =$(this).val();&#13;
# &#13;
#         if(! test.match(/^[^']{0,}$/)){&#13;
#             $(this).val(test.replace(/[\u0027]+/ig,''));&#13;
#         }&#13;
# &#13;
#     });&#13;
# &#13;
#     $("input").keyup(function(event){&#13;
#         var test =$(this).val();&#13;
#         if(! test.match(/^[^']{0,}$/)){&#13;
#             $(this).val(test.replace(/[\u0027]+/ig,''));&#13;
#         }&#13;
#     });&#13;
#     $(':input').on('input paste',function(){$(this).keyup();});&#13;
# 	&#13;
# 	// nocsrf&#13;
#    	var csrfToken = 'MTU4MzgyNTY5MjYwVG12NUhlc0k3ZmpiY2FjT0MyZUx0cXhxUkpzZ2Nj';&#13;
#    	var csrfTokenInput = document.createElement("input");&#13;
#    	$(csrfTokenInput).attr ('type', 'hidden').attr('name', 'nti_JUFBJUI3JUJDJUFFJUI5JTdDJTdCJUJDeSVBQnklQkMlODElQTklQjclODElQjclQjglN0MlQjMlN0QlQjQlODElQkElQkQlN0M').val (csrfToken);&#13;
#    	&#13;
#    	$('form').each (function (index) {&#13;
#    		$(this).append(csrfTokenInput);&#13;
#    		//console.log($(this).serialize());&#13;
#    	});&#13;
# })&#13;
# </script>&#13;
# &#13;
# <!---->&#13;
# <!--購物車追蹤頁start-->&#13;
# <!--<!--購物車追蹤頁END-->&#13;
# &#13;
# <!--購物結帳完成頁start-->&#13;
# <!--<!--購物結帳完成頁END-->&#13;
# &#13;
# <!--會員註冊確認頁start-->&#13;
# <!---->&#13;
# <!--會員註冊確認頁END-->&#13;
# &#13;
# <!---->&#13;
# &#13;
# &#13;
# &#13;
# <!---->&#13;
# <!---->&#13;
# &#13;
# &#13;
# <!---->&#13;
# <!---->&#13;
# &#13;
# &#13;<!---->&#13;
# &#13;
# &#13;
# <!-- 20170128 END	-->&#13;
# <div id="floorFix"><div class="floorAll">&#13;
# <ul class="floorManger">&#13;
# <li class="floor2 floor"><a href="#1f">食品雜貨</a></li>&#13;
# <li class="floor6 floor"><a href="#2f">清潔美容</a></li>&#13;
# <li class="floor4 floor"><a href="#3f">品牌鍋具</a></li>&#13;
# <li class="floor3 floor"><a href="#4f">調理家電</a></li>	&#13;
# <li class="floor1 floor"><a href="#5f">儲存媒體</a></li>&#13;
# <li class="floor5 floor"><a href="#6f">服飾推薦</a></li>&#13;
# <li class="floor10 floor"><a href="https://www.rt-mart.com.tw/member/index.php?action=product_trace_list">追蹤清單</a></li>&#13;
# <li class="floor7 floor"><a href="https://www.rt-mart.com.tw/direct/index.php?action=shopping_cart&amp;web_cart_myAct=SHOPPING_CART">購物車</a></li>&#13;
# <li class="floor8 floor"><a href="https://www.rt-mart.com.tw/member/index.php?action=account">會員中心</a></li>&#13;
# <li class="floor9 floor"><a href="#">TOP</a></li>&#13;
# </ul></div>&#13;
# &#13;
# &#13;
# <!-- 2018/02/02 Riley 掛飾start -->&#13;
# &#13;
# <!--   <div id="cnyStrap04">
#     <img src="http://www.rt-mart.com.tw/website/uploads/web_banner/18cny02/18cnystrap4.png">
#   </div>
#
#   <div id="cnyStrap05">
#     <img src="http://www.rt-mart.com.tw/website/uploads/web_banner/18cny02/18cnystrap5.png">
#   </div>
#
#   <div id="cnyStrap06">
#     <img src="http://www.rt-mart.com.tw/website/uploads/web_banner/18cny02/18cnystrap6.png">
#   </div>
#
#   <div id="cnyStrap07">
#     <img src="http://www.rt-mart.com.tw/website/uploads/web_banner/18cny02/18cnystrap7.png">
#   </div> -->&#13;
#   &#13;
# <!-- 2018/02/02 Riley 掛飾end -->&#13;
# &#13;
# &#13;
# </div>&#13;
# &#13;
# &#13;
# &#13;
# <div id="show_srm_outer" style="position:fixed; top:0 ;left:0; border: 0px red solid; width: 1px; height: 450px; display: none;">&#13;
# 		<input id="show_off_button" type="button" onclick="show_off_srm();" />&#13;
# 		<div id="show_srm" style="border: 0px red solid; width: 1px; height: 100%;">&#13;
# 			<input type="hidden" id="is_srm_load" name="is_srm_load" value="0" />&#13;
# 			<input type="hidden" id="is_srm_open" name="is_srm_open" value="0" />&#13;
# 			<iframe id="srm_iframe" style="width: 1px; height: 100%; display: none;" src=""></iframe>&#13;
# 		</div>&#13;
# 	</div>&#13;
# &#13;
# &#13;
# &#13;
# </body>&#13;
# <script>&#13;
# &#13;
# //回到頂端start&#13;
# (function () {&#13;
# &#13;
# &#13;
# $button = $("#goTopButton"),&#13;
# $body = $(document),&#13;
# $win = $(window);&#13;
# &#13;
# window.goTopMove = function () {&#13;
# var scrollH = $body.scrollTop(),&#13;
# winH = $win.height();&#13;
# if(scrollH &gt; 100) {&#13;
# &#13;
# $(".floorAll").stop().animate({top:"20px"});&#13;
# &#13;
# }else{&#13;
# $(".floorAll").stop().animate({top:"270px"});&#13;
# &#13;
# }&#13;
# };&#13;
# $win.on({&#13;
# scroll: function() {goTopMove();},&#13;
# resize: function() {goTopMove();}&#13;
# });&#13;
# } )();&#13;
# //回到頂端end&#13;
# &#13;
# &#13;
# &#13;
# &#13;
# &#13;
# &#13;
# &lt;!-- 20170128 update : Stanley Author : Jin	--&gt;&#13;
# &#13;
# $(document).ready(function () {&#13;
# &#13;
# 	function footerPosition(){&#13;
# 	var winHeight = $(window).height()*0.07+'px';&#13;
# 	$(".warning2").css("height", winHeight);&#13;
# 	$(".warning2").css("line-height", winHeight);&#13;
# 	$(".FOR_FOOTER").css("margin-bottom", winHeight);&#13;
# 	}&#13;
# 	footerPosition();&#13;
# 	$( window ).resize(function() {&#13;
# 		footerPosition();&#13;
# 	});&#13;
# &#13;
# });&#13;
# &#13;
# &#13;
# /*&#13;
# 2017/03/06 JIN&#13;
# 自動上下架開始&#13;
# &#13;
# */&#13;
# 		&#13;
# &#13;
# 		var start_time = new Date("2018/04/18 00:00:00");//上架時間&#13;
# 		var end_time = new Date("2018/04/25 23:59:59"); //下架時間&#13;
# 		var now_time = new Date();&#13;
# 		/*var count_time = (end_time - start_time)/1000; */&#13;
# &#13;
# 		&#13;
# 		&#13;
# 		var ad = '&lt;div id="idleAd" style=""&gt;&lt;div class="inner"&gt;&lt;p&gt;&lt;/p&gt;&lt;div class="box_0"&gt;&lt;a href="https://goo.gl/ppUf6u" target=_blank&gt;&lt;img class="modal-content" src="https://www.rt-mart.com.tw/website/uploads/web_banner/180418_index_cover.jpg" id="img01"&gt;&lt;/a&gt;&lt;/div&gt;&lt;span class="close"&gt;【關閉 X】&lt;/span&gt;&lt;/div&gt;&lt;div class="overlap" id="overlap"&gt;&lt;/div&gt;&lt;/div&gt;';&#13;
# &#13;
# &#13;
# &#13;
# &#13;
# 		 if(now_time &gt;= start_time &amp;&amp; now_time &lt;= end_time){&#13;
# 			$("#coverad").append(ad);&#13;
# 			&#13;
# 			var myVar = setInterval(function(){ myTimer() }, 3000);&#13;
# 			function myTimer() {&#13;
# 			$("#idleAd").slideUp(1000);&#13;
# 			}&#13;
# 				&#13;
# 			$(".close").click(function(){&#13;
# 			$("#idleAd").css("display", "none");&#13;
# 			});&#13;
# 							&#13;
# 			$(".overlap").click(function(){&#13;
# 			$("#idleAd").css("display", "none");&#13;
# 			});&#13;
# &#13;
# 		 }&#13;
# 				&#13;
# 				&#13;
# 				&#13;
# 				&#13;
# &#13;
# &#13;
# /*&#13;
# 2017/03/06 JIN&#13;
# 自動上下架結束&#13;
# &#13;
# */	&#13;
# &#13;
# //my客服&#13;
# 	var a = document.createElement("a");&#13;
# 	a.textContent = "My客服";&#13;
# 	a.setAttribute('href', "javascript: void(0)");&#13;
# 	&#13;
# 	var ul = document.querySelector('#floorFix .floorAll .floorManger');&#13;
# 	var newli = document.createElement('li');&#13;
# 	newli.className = "floor icon-service";&#13;
# 	newli.appendChild(a);&#13;
# 	&#13;
# 	&#13;
# 	// do what you need to the new li, including giving it an id if you want&#13;
# 	ul.appendChild(newli);&#13;
# 	//ul.appendChild(newli);&#13;
# 	&#13;
# 	&#13;
# 	&#13;
# 	$("#floorFix .icon-service").click( function() {&#13;
# 		if( /Android|webOS|iPhone|iPad|iPod|BlackBerry|IEMobile|Opera Mini/i.test(navigator.userAgent) ) {&#13;
# 			location.href = 'https://contact-center.hithot.cc/rt-mart/index.php?eservice=scrollbar&amp;qaCategory=general';&#13;
# 		} else {&#13;
# 			show_off_srm();&#13;
# 		}&#13;
#     });&#13;
# 	&#13;
# 	function show_off_srm(){&#13;
# 		var headerHeight = $('.rtmartHEADER').height() + 10;&#13;
# 		var windowHeight = window.innerHeight - 10;&#13;
# 		var windowWidth = $(window).width();&#13;
# 		var percentageWidth = 0.45;&#13;
# 		var buttonWidth = 45;&#13;
# 	&#13;
# 		if(document.getElementById('is_srm_load').value == '0'){&#13;
# 			document.getElementById('show_srm_outer').style.width = windowWidth*percentageWidth+buttonWidth+'px';&#13;
# 			document.getElementById('show_srm_outer').style.margin = headerHeight+'px 1px 1px 1px';&#13;
# 			document.getElementById('show_srm').style.width = windowWidth*percentageWidth+'px';&#13;
# 			document.getElementById('srm_iframe').style.width = windowWidth*percentageWidth+'px';&#13;
# 			document.getElementById('show_srm_outer').style.left = windowWidth - (windowWidth*percentageWidth+buttonWidth)+'px';&#13;
# 			document.getElementById('show_srm_outer').style.height = (windowHeight - headerHeight)+'px';&#13;
# 			document.getElementById('show_srm_outer').style.display = 'block';&#13;
# 			document.getElementById('is_srm_open').value = '1';&#13;
# 			&#13;
# 			document.getElementById('show_srm_outer').style.left = windowWidth - (windowWidth*percentageWidth+buttonWidth)+'px';&#13;
# 			document.getElementById('srm_iframe').style.display = 'block';&#13;
# 			document.getElementById('show_srm_outer').style.display = 'block';&#13;
# 			document.getElementById('is_srm_load').value = '1';&#13;
# 			document.getElementById('is_srm_open').value = '1';&#13;
# 			document.getElementById('srm_iframe').src = 'https://contact-center.hithot.cc/rt-mart/index.php?eservice=qrcode&amp;qaCategory=general';&#13;
# &#13;
# 		} else {&#13;
# 			if(document.getElementById('is_srm_open').value == '1'){&#13;
# 				document.getElementById('show_srm_outer').style.left = windowWidth - buttonWidth+'px';&#13;
# 				document.getElementById('show_srm_outer').style.display = 'none';&#13;
# 				document.getElementById('is_srm_open').value = '0';&#13;
# 			} else {&#13;
# 				document.getElementById('show_srm_outer').style.width = windowWidth*percentageWidth+buttonWidth+'px';&#13;
# 				document.getElementById('show_srm_outer').style.margin = headerHeight+'px 1px 1px 1px';&#13;
# 				document.getElementById('show_srm').style.width = windowWidth*percentageWidth+'px';&#13;
# 				document.getElementById('srm_iframe').style.width = windowWidth*percentageWidth+'px';&#13;
# 				document.getElementById('show_srm_outer').style.left = windowWidth - (windowWidth*percentageWidth+buttonWidth)+'px';&#13;
# 				document.getElementById('show_srm_outer').style.height = (windowHeight - headerHeight)+'px';&#13;
# 				document.getElementById('show_srm_outer').style.display = 'block';&#13;
# 				document.getElementById('is_srm_open').value = '1';&#13;
# 			}	&#13;
# 		}&#13;
# 	}&#13;
# </script>	&#13;
# <script async="" type="text/javascript" src="/_Incapsula_Resource?SWJIYLWA=719d34d31c8e3a6e6fffd425f7e032f3&amp;ns=3&amp;cb=1536622401"></script>
# </html>

# %%
dataList=[]
CateList=HomeDoc(".footerNavContent>ul>li>h3>a")
for Eachcast in CateList.items():
#     print(Eachcast.attr("href"))
    CateRes = requests.get(Eachcast.attr("href"))
# HomeRes.text
    CateDoc = pq(CateRes.text)
    CateList2=CateDoc(".classify_title>a")
    for Eachcast2 in CateList2.items():
        if Eachcast2.attr("href")=="javascript: void(0);":
            continue
        print(Eachcast2.attr("href"))
#         CateRes2 = requests.get(Eachcast2.attr("href"))
#         CateDoc2 = pq(CateRes2.text)
#         #part2
#         pg=1
#         nextPgDoc=CateDoc2
#         while True:
#             print(len(CateDoc2(".indexProList")))
#             itemLi=nextPgDoc(".indexProList")
# #           print(len(itemLi),CateRes2.url+"&prod_size=&p_data_num=18&usort=auto_date%2CDESC&page={}".format(pg))
#             for eachItemDoc in itemLi.items():
#                 dataDict={}
#                 dataDict["title"]=eachItemDoc("h5").text()
#                 dataDict["price"]=eachItemDoc(".for_pricebox").text()
#                 dataList.append(dataDict)
#                 print(eachItemDoc("h5").text())
#                 print(eachItemDoc(".for_pricebox").text())
#             pg+=1
#             if len(itemLi)==0:
#                 break
#             nextPgRes = requests.get(CateRes2.url+"&prod_size=&p_data_num=18&usort=aut\
#             o_date%2CDESC&page={}".format(pg))
#             nextPgDoc = pq(nextPgRes.text)
# Out:
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3869
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3870
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3878
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=37536
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=24282
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3794
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3795
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3796
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3797
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3798
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3799
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3762
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3763
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3765
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=37696
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3766
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3768
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3767
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3769
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3770
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3782
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3787
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3790
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3802
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3803
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3804
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3808
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=4080
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3756
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=30652
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=30769
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=20670
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3757
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3760
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=25036
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3759
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=47284
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3813
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=25517
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3812
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3811
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=25894
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=25543
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3810
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=73550
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3829
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3828
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3826
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=26960
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3838
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3839
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3840
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3841
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=31900
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=31822
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=32043
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3834
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3832
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=26596
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=25127
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=28793
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=25140
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=25153
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3843
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3853
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3848
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3852
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3854
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3847
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3851
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3842
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=25023
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3846
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3850
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=31029
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=30977
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=31042
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=31003
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=31016
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=30990
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3771
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=26401
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3775
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3776
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=20358
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3774&prod_size=&p_data_num=&usort=prod_sales_count,DESC
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3777
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3779
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3773
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=103540
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=103710
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=103064
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=27103
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=20106
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=3859
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=20046
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=20058
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=16821
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=20094
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=73089
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=71703
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=71538
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=117106
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=71670
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=115916
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=71637
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=116596
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=71604
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=117582
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=117616
# https://www.rt-mart.com.tw/direct/index.php?action=product_sort&prod_sort_uid=116970

# %%
print(dataList)
# Out:
# [{'title': 'SEGAFREDO 中烘咖啡粉250G', 'price': '$149'}, {'title': 'LAVAZZA PRONTISSIMO 醇厚即溶咖啡', 'price': '$299'}, {'title': 'LAVAZZA PRONTISSIMO 經典即溶咖啡', 'price': '$299'}, {'title': 'LAVAZZA 經典奶香咖啡豆1KG', 'price': '$699'}, {'title': '義大利Auchan巧克力麵包', 'price': '$55'}, {'title': 'Coppini特級初榨橄欖油', 'price': '$450'}, {'title': "Costa d\\'Oro特級初榨橄欖油擠壓瓶", 'price': '$179'}, {'title': 'Eldorada原味洋芋片(桶裝)400g', 'price': '$359'}, {'title': 'PONTI 紅酒醋 酸度6%', 'price': '$99'}, {'title': 'URBANI 夏季松露菌菇醬 80G', 'price': '$279'}, {'title': '義大利Covim歐羅黃金咖啡粉250g/袋', 'price': '$129'}, {'title': '義大利Covim皇家咖啡分粉250g/袋', 'price': '$99'}, {'title': 'Coelsanus去籽黑橄欖 150g', 'price': '$116'}, {'title': 'Coelsanus黑橄欖 200g', 'price': '$107'}, {'title': 'MMM100%葵花油1L/瓶', 'price': '$139'}, {'title': '義大利進口KIMBO黃金香濃咖啡豆', 'price': '$719'}, {'title': '義大利進口KIMBO濃醇香氣咖啡豆', 'price': '$520'}, {'title': '(B)義大利Rummo74號綜合形狀麵', 'price': '$62'}, {'title': '義大利Illy單一產區衣索匹亞咖啡豆', 'price': '$305'}, {'title': '義大利Illy單一產區巴西咖啡豆', 'price': '$305'}, {'title': '義大利Illy單一產區瓜地馬拉咖啡豆', 'price': '$305'}, {'title': '義大利進口大蒜調味橄欖油 250ml', 'price': '$199'}, {'title': '義大利進口迷迭香調味橄欖油 250ml', 'price': '$199'}, {'title': '義大利進口辣椒調味橄欖油 250ml', 'price': '$199'}, {'title': '義大利進口甜心卡布里辣椒佐蔬菜', 'price': '$249'}, {'title': '義大利Arabica咖啡粉-肯亞AA級 250g', 'price': '$169'}, {'title': '義大利Corsini典藏咖啡粉', 'price': '$79'}, {'title': 'Auchan義大利頂級細緻橄欖油', 'price': '$249'}, {'title': 'Auchan義大利榛果威化餅', 'price': '$79'}, {'title': 'Auchan 義大利頂級果香橄欖油', 'price': '$260'}, {'title': 'Auchan義大利剝皮番茄', 'price': '$36'}, {'title': '義大利Novi 99% 黑巧克力- 75g', 'price': '$99'}, {'title': '(B)Auchan義大利特級初榨橄欖油', 'price': '$249'}, {'title': 'Auchan義大利純橄欖油', 'price': '$239'}, {'title': 'Auchan義大利牛奶威化餅', 'price': '$69'}, {'title': '義大利De Cecco大蝴蝶結麵500g', 'price': '$77'}, {'title': 'Auchan義大利蜂蜜餅乾', 'price': '$69'}, {'title': 'Auchan義大利香草餅乾 500g/包', 'price': '$99'}, {'title': '義大利Illy中烘焙濾泡咖啡粉', 'price': '$305'}, {'title': '義大利Illy低咖啡因咖啡粉 250g', 'price': '$305'}, {'title': '義大利Corsini典藏金咖啡豆', 'price': '$161'}, {'title': '義大利Bonomi 手指餅乾 500g', 'price': '$145'}, {'title': 'Auchan義大利羅勒青醬(不含大蒜)', 'price': '$116'}, {'title': 'Auchan義大利青醬(大蒜/橄欖油調味)', 'price': '$79'}, {'title': 'Auchan義大利韃靼香料沾醬', 'price': '$69'}, {'title': 'Auchan義大利牛奶威化餅- 225g', 'price': '$117'}, {'title': '義大利De Cecco直麵500g', 'price': '$71'}, {'title': 'Auchan義式阿拉比卡咖啡粉250g/包', 'price': '$116'}, {'title': 'Auchan義大利綠橄欖- 300g/瓶', 'price': '$50'}, {'title': '義大利Illy中度烘焙咖啡粉', 'price': '$305'}, {'title': '義大利DE CECCO整顆去皮番茄罐400g', 'price': '$65'}, {'title': '義大利DE CECCO特級初榨橄欖油', 'price': '$278'}, {'title': 'San Carlo杜林麵包棍小包裝125g', 'price': '$79'}, {'title': 'IL GREZZO頂級橄欖油未過濾', 'price': '$383'}, {'title': 'Auchan義大利番茄泥(去籽)', 'price': '$53'}, {'title': 'Costa d Oro葡萄籽油', 'price': '$203'}, {'title': '聖沛黎洛氣泡礦泉水 X6', 'price': '$189'}, {'title': '【兩件免運特惠中】義大利Illy中度烘培摩卡咖啡粉', 'price': '$305'}, {'title': '義大利De CeccoN.34螺旋麵1kg/包', 'price': '$129'}, {'title': '義大利DE CECCO拿玻里麵醬 400g/瓶', 'price': '$89'}, {'title': '義大利LAVAZZA香醇濃縮咖啡豆1kg', 'price': '$701'}, {'title': '義大利Illy摩卡咖啡粉 250g/罐', 'price': '$305'}, {'title': 'Auchan義式千層麵皮500g/盒', 'price': '$116'}, {'title': '義大利Corsini醇金咖啡粉250g/包', 'price': '$96'}, {'title': '義大利Corsini醇金濃縮咖啡粉', 'price': '$107'}, {'title': '義大利Arabica咖啡豆-巴西500g', 'price': '$305'}, {'title': 'Auchan義大利巧克力威化餅', 'price': '$79'}, {'title': '義大利Bonomi小麥千層餅', 'price': '$71'}, {'title': 'Auchan義大利醃漬去核橄欖', 'price': '$59'}, {'title': 'Auchan義大利切里尼拉醃漬綠橄欖', 'price': '$197'}, {'title': '康迪傳統杏桃果醬170g', 'price': '$98'}, {'title': '康迪傳統無花果果醬170g', 'price': '$98'}, {'title': '沛綠雅氣泡天然礦泉水 330ml*4瓶/組', 'price': '$139'}, {'title': '沛綠雅氣泡天然礦泉水-檸檬四入組', 'price': '$139'}, {'title': '沛綠雅氣泡天然礦泉水-葡萄柚四入組', 'price': '$139'}, {'title': '(B)evian依雲天然礦泉水1000mlx3瓶', 'price': '$199'}, {'title': '(B)富維克礦泉水 500mlx6瓶/組', 'price': '$195'}, {'title': 'LOTTE KOUME小梅糖-青梅季節限定', 'price': '$79'}, {'title': '固力果番茄脆棒(9袋入)', 'price': '$130'}, {'title': '日東奶茶', 'price': '$210'}, {'title': '日東皇家奶茶包', 'price': '$210'}, {'ti ...
